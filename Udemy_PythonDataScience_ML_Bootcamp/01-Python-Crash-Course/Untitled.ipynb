# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import dates as mplt_dates
from datetime import datetime

# %%
df =  pd.read_csv('ndt7.csv')
df
# Out:
#     MinRTTValue  DownloadRetransValue  UploadValue  DownloadValue  \
# 0       299.000              1.610887    23.719233      20.859466
# 1       299.375              0.799899     2.502069      25.157392
# 2       300.405              0.195314    24.515576      24.944061
# 3       299.276              0.291067     2.962271      23.417663
# 4       298.954              0.503149    21.940971      24.494629
# 5       303.166              0.302159    24.452687      25.067811
# 6       297.658              0.417224    24.037094      24.817605
# 7       298.961              0.276521    24.101228      25.082404
# 8       303.548              0.267649    23.992779      24.980382
# 9       299.404              0.325944    24.568113      23.826083
# 10      301.025              0.302741     2.014622      24.842303
# 11      343.354              1.292913     0.183310      22.851676
# 12      300.585              0.308016     2.941389      23.518133
# ...

# %%
fig, ax = plt.subplots(figsize=(13,7))
styles = ['b','g','y', 'r','m']
downloads = df_clean1['DownloadValue']
uploads = df['UploadValue']
rtts = df['MinRTTValue']
#plt.plot(df['date'],rtts,marker='o', color='green', linestyle='dashed',linewidth=2, markersize=5, label ='MinRTT')
plt.plot(df['date'],downloads,marker='o', color='orange', linestyle='dashed',linewidth=2, markersize=7, label ='Download Speed')
plt.plot(df['date'],uploads,marker='o', color='blue', linestyle='dashed',linewidth=2, markersize=12,label ='Upload Speed')
plt.legend()
#df_clean1.date = pd.to_datetime(df_clean1['TestStartTime'], format='%Y-%m-%d')

# %%
fig, ax = plt.subplots(figsize=(13,7))
plt.plot(df['date'],rtts,marker='o', color='green', linestyle='dashed',linewidth=2, markersize=5, label ='MinRTT')
